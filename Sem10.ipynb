# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaAnk/Python/blob/main/Sem10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача №63. Решение в группах
# 1. Изобразите отношение households к population с
# помощью точечного графика
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график
# 3. Представить гистограмму по housing_median_age
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
import pandas as pd

# %%
df=pd.read_csv("sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import seaborn as sns

# %% [markdown]
# . Изобразите отношение households к population с
# помощью точечного графика

# %%
sns.scatterplot(data=df, x ='households', y='population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %% [markdown]
# Визуализировать longitude по отношения к
# median_house_value, используя линейный график

# %%
sns.relplot(x="longitude",y="median_house_value", kind="line",data=df)

# %% [markdown]
#  Представить гистограмму по housing_median_age

# %%
sns.histplot(data=df, x="housing_median_age")
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
sns.histplot(data=df,x="median_house_value", hue="housing_median_age")
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# Задача №65. Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
# ● Использовать 2-3 точечных графика
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# ● Использовать PairGrid с типом графика на ваш выбор
# ● Изобразить Heatmap
# ● Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 301     Gentoo     Biscoe            52.5           15.6              221.0
# 154  Chinstrap      Dream            51.3           19.2              193.0
# 84      Adelie      Dream            37.3           17.8              191.0
# 31      Adelie      Dream            37.2           18.1              178.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 144     Adelie      Dream            37.3           16.8              192.0
# 10      Adelie  Torgersen            37.8           17.1              186.0
# 269     Gentoo     Biscoe            45.2           15.8              215.0
# 109     Adelie     Biscoe            43.2           19.0              197.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
#
#      body_mass_g     sex
# 301       5450.0    Male
# 154       3650.0    Male
# 84        3350.0  Female
# 31        3900.0    Male
# 2         3250.0  Female
# 144       3000.0  Female
# 10        3300.0     NaN
# 269       5300.0    Male
# 109       4775.0    Male
# 101       4725.0    Male

# %% [markdown]
# ● Использовать 2-3 точечных графика
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='sex', size='body_mass_g' , style='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='flipper_length_mm', hue='sex', size='body_mass_g' , style='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='body_mass_g', hue='sex', size='flipper_length_mm' , style='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# ● Использовать PairGrid с типом графика на ваш выбор

# %%
g=sns.PairGrid(data=penguins,)
g.map(sns.scatterplot)

# %% [markdown]
# ● Изобразить Heatmap

# %%
corr_penguins = penguins.corr().round(2)
corr_penguins
# Out:
# <ipython-input-21-a29146e1c0b6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_penguins = penguins.corr().round(2)
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm               1.00          -0.24               0.66
# bill_depth_mm               -0.24           1.00              -0.58
# flipper_length_mm            0.66          -0.58               1.00
# body_mass_g                  0.60          -0.47               0.87
#
#                    body_mass_g
# bill_length_mm            0.60
# bill_depth_mm            -0.47
# flipper_length_mm         0.87
# body_mass_g               1.00

# %%
sns.heatmap(corr_penguins, annot=True, linewidths=2, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ● Использовать 2-3 гистограммы

# %%
sns.histplot(data=penguins, x='flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='body_mass_g')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# Задача №67. Решение в группах
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm']>=42, 'height_group'] = 'high'
penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 208  Chinstrap      Dream            45.2           16.6              191.0
# 163  Chinstrap      Dream            51.7           20.3              194.0
# 55      Adelie     Biscoe            41.4           18.6              191.0
# 141     Adelie      Dream            40.6           17.2              187.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 68      Adelie  Torgersen            35.9           16.6              190.0
# 340     Gentoo     Biscoe            46.8           14.3              215.0
# 313     Gentoo     Biscoe            49.5           16.1              224.0
# 209  Chinstrap      Dream            49.3           19.9              203.0
# 75      Adelie  Torgersen            42.8           18.5              195.0
#
#      body_mass_g     sex height_group
# 208       3250.0  Female         high
# 163       3775.0    Male         high
# 55        3700.0    Male          NaN
# 141       3475.0    Male          NaN
# 101       4725.0    Male          NaN
# 68        3050.0  Female          NaN
# 340       4850.0  Female         high
# 313       5650.0    Male         high
# 209       4050.0    Male         high
# 75        4250.0    Male         high

# %%
penguins.loc[(penguins['bill_length_mm']>=35) & (penguins['bill_length_mm']<42), 'height_group'] = 'middle'
penguins.sample(10)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 84      Adelie   Dream            37.3           17.8              191.0
# 101     Adelie  Biscoe            41.0           20.0              203.0
# 252     Gentoo  Biscoe            45.1           14.5              207.0
# 308     Gentoo  Biscoe            47.5           14.0              212.0
# 199  Chinstrap   Dream            49.0           19.6              212.0
# 313     Gentoo  Biscoe            49.5           16.1              224.0
# 289     Gentoo  Biscoe            50.7           15.0              223.0
# 290     Gentoo  Biscoe            47.7           15.0              216.0
# 188  Chinstrap   Dream            47.6           18.3              195.0
# 27      Adelie  Biscoe            40.5           17.9              187.0
#
#      body_mass_g     sex height_group
# 84        3350.0  Female       middle
# 101       4725.0    Male       middle
# 252       5050.0  Female         high
# 308       4875.0  Female         high
# 199       4300.0    Male         high
# 313       5650.0    Male         high
# 289       5550.0    Male         high
# 290       4750.0  Female         high
# 188       3850.0  Female         high
# 27        3200.0  Female       middle

# %%
penguins.loc[penguins['bill_length_mm']<35, 'height_group'] = 'low'
penguins.sample(50)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 136     Adelie      Dream            35.6           17.5              191.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 252     Gentoo     Biscoe            45.1           14.5              207.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# 223     Gentoo     Biscoe            50.0           15.2              218.0
# 220     Gentoo     Biscoe            46.1           13.2              211.0
# 189  Chinstrap      Dream            52.0           20.7              210.0
# 186  Chinstrap      Dream            49.7           18.6              195.0
# 124     Adelie  Torgersen            35.2           15.9              186.0
# 41      Adelie      Dream            40.8           18.4              195.0
# 37      Adelie      Dream            42.2           18.5              180.0
# 254     Gentoo     Biscoe            49.1           14.8              220.0
# 145     Adelie      Dream            39.0           18.7              185.0
# 184  Chinstrap      Dream            42.5           16.7              187.0
# 93      Adelie      Dream            39.6           18.1              186.0
# 107     Adelie     Biscoe            38.2           20.0              190.0
# 272     Gentoo     Biscoe            45.1           14.4              210.0
# 127     Adelie  Torgersen            41.5           18.3              195.0
# 154  Chinstrap      Dream            51.3           19.2              193.0
# 8       Adelie  Torgersen            34.1           18.1              193.0
# 11      Adelie  Torgersen            37.8           17.3              180.0
# 141     Adelie      Dream            40.6           17.2              187.0
# 131     Adelie  Torgersen            43.1           19.2              197.0
# 246     Gentoo     Biscoe            44.5           14.3              216.0
# 297     Gentoo     Biscoe            51.1           16.3              220.0
# 337     Gentoo     Biscoe            48.8           16.2              222.0
# 32      Adelie      Dream            39.5           17.8              188.0
# 60      Adelie     Biscoe            35.7           16.9              185.0
# 105     Adelie     Biscoe            39.7           18.9              184.0
# 218  Chinstrap      Dream            50.8           19.0              210.0
# 101     Adelie     Biscoe            41.0           20.0              203.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 113     Adelie     Biscoe            42.2           19.5              197.0
# 153  Chinstrap      Dream            50.0           19.5              196.0
# 332     Gentoo     Biscoe            43.5           15.2              213.0
# 341     Gentoo     Biscoe            50.4           15.7              222.0
# 66      Adelie     Biscoe            35.5           16.2              195.0
# 52      Adelie     Biscoe            35.0           17.9              190.0
# 88      Adelie      Dream            38.3           19.2              189.0
# 198  Chinstrap      Dream            50.1           17.9              190.0
# 135     Adelie      Dream            41.1           17.5              190.0
# 134     Adelie      Dream            38.1           17.6              187.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 57      Adelie     Biscoe            40.6           18.8              193.0
# 320     Gentoo     Biscoe            48.5           15.0              219.0
# 330     Gentoo     Biscoe            50.5           15.2              216.0
# 132     Adelie      Dream            36.8           18.5              193.0
# 331     Gentoo     Biscoe            49.8           15.9              229.0
# 327     Gentoo     Biscoe            53.4           15.8              219.0
# 13      Adelie  Torgersen            38.6           21.2              191.0
#
#      body_mass_g     sex height_group
# 136       3175.0  Female       middle
# 64        2850.0  Female       middle
# 252       5050.0  Female         high
# 12        3200.0  Female       middle
# 223       5700.0    Male         high
# 220       4500.0  Female         high
# 189       4800.0    Male         high
# 186       3600.0    Male         high
# 124       3050.0  Female       middle
# 41        3900.0    Male       middle
# 37        3550.0  Female         high
# 254       5150.0  Female         high
# 145       3650.0    Male       middle
# 184       3350.0  Female         high
# 93        4450.0    Male       middle
# 107       3900.0    Male       middle
# 272       4400.0  Female         high
# 127       4300.0    Male       middle
# 154       3650.0    Male         high
# 8         3475.0     NaN          low
# 11        3700.0     NaN       middle
# 141       3475.0    Male       middle
# 131       3500.0    Male         high
# 246       4100.0     NaN         high
# 297       6000.0    Male         high
# 337       6000.0    Male         high
# 32        3300.0  Female       middle
# 60        3150.0  Female       middle
# 105       3550.0    Male       middle
# 218       4100.0    Male         high
# 101       4725.0    Male       middle
# 321       5600.0    Male         high
# 113       4275.0    Male         high
# 153       3900.0    Male         high
# 332       4650.0  Female         high
# 341       5750.0    Male         high
# 66        3350.0  Female       middle
# 52        3450.0  Female       middle
# 88        3950.0    Male       middle
# 198       3400.0  Female         high
# 135       3900.0    Male       middle
# 134       3425.0  Female       middle
# 70        3600.0  Female          low
# 57        3800.0    Male       middle
# 320       4850.0  Female         high
# 330       5000.0  Female         high
# 132       3500.0  Female       middle
# 331       5950.0    Male         high
# 327       5500.0    Male         high
# 13        3800.0    Male       middle

# %% [markdown]
# Задача №69. Решение в группах
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='height_group')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>
